# %% [markdown]
# # Analysis Noun Attitude in R
#
# This code is main edited by Enze Wang
#
# Fixed by Yicen Liu and Hua Tong
#
# # Attention
#
# Please put four .csv file in data folder and put this code in main folder instead of code folder.
#
# This code want to do test for business on whether change or fix their service or food to increase star rating.

# %%
if (!require(ggplot2)){
  install.packages("ggplot2")
}
if (!require(DAAG)){
  install.packages("DAAG")
}
if (!require(glmnet)){
  install.packages("glmnet")
}
if (!require(grid)){
  install.packages("grid")
}
if (!require(gridExtra)){
  install.packages("gridExtra")
}
if (!require(MASS)){
  install.packages("MASS")
}
if (!require(car)){
  install.packages("car")
}
if (!require(corrplot)){
  install.packages("corrplot")
}
if (!require(leaps)){
  install.packages("leaps")
}
if (!require(caret)){
  install.packages("caret")
}
if (!require(psych)){
  install.packages("psych")
}
if (!require(stats)){
  install.packages("stats")
}
if (!require(broom)){
  install.packages("broom")
}
if (!require(gbm)){
  install.packages("gbm")
}
if (!require(randomForest)){
  install.packages("randomForest")
}
if (!require(olsrr)){
  install.packages("olsrr")
}
if (!require(regclass)){
  install.packages("regclass")
}
if (!require(pROC)){
  install.packages("pROC")
}
# Out:
# Loading required package: ggplot2
#
# Loading required package: DAAG
#
# Loading required package: lattice
#
# Loading required package: glmnet
#
# Loading required package: Matrix
#
# Loaded glmnet 4.0-2
#
# Loading required package: grid
#
# Loading required package: gridExtra
#
# Loading required package: MASS
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:DAAG’:
#
#     hills
#
#
# Loading required package: car
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:DAAG’:
#
#     vif
#
#
# Loading required package: corrplot
#
# corrplot 0.84 loaded
#
# Loading required package: leaps
#
# Loading required package: caret
#
# Loading required package: psych
#
#
# Attaching package: ‘psych’
#
#
# The following object is masked from ‘package:car’:
#
#     logit
#
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha
#
#
# Loading required package: broom
#
# Loading required package: gbm
#
# Loaded gbm 2.1.8
#
# Loading required package: randomForest
#
# randomForest 4.6-14
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:psych’:
#
#     outlier
#
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
#
# Loading required package: olsrr
#
#
# Attaching package: ‘olsrr’
#
#
# The following object is masked from ‘package:MASS’:
#
#     cement
#
#
# The following object is masked from ‘package:datasets’:
#
#     rivers
#
#
# Loading required package: regclass
#
# Loading required package: bestglm
#
# Loading required package: VGAM
#
# Loading required package: stats4
#
# Loading required package: splines
#
#
# Attaching package: ‘VGAM’
#
#
# The following objects are masked from ‘package:psych’:
#
#     fisherz, logistic, logit
#
#
# The following object is masked from ‘package:caret’:
#
#     predictors
#
#
# The following object is masked from ‘package:car’:
#
#     logit
#
#
# Loading required package: rpart
#
# Important regclass change from 1.3:
# All functions that had a . in the name now have an _
# all.correlations -> all_correlations, cor.demo -> cor_demo, etc.
#
#
#
# Attaching package: ‘regclass’
#
#
# The following object is masked from ‘package:lattice’:
#
#     qq
#
#
# Loading required package: pROC
#
# Type 'citation("pROC")' for a citation.
#
#
# Attaching package: ‘pROC’
#
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var

# %%
Word_Review_Matrix=read.csv("data/Word_Review_Matrix.csv")
Review=read.csv("data/pizza_review.csv")
Noun_Variables_Important=read.csv("data/Noun_Variables_Important.csv")

# %%
Word_Review_Matrix
# Out:
#       X     review_id              business_id            stars pizza food
# 1      0    hfXVxrlD6fr1kXfz6sR13Q J9f-9Prw2YVM-fiZqv2fmQ 2     NA    NA
# 2      1    EDQpLLFiAxeSxWI5ipwzBQ lpel3pRFAzlow7u2TJMz4Q 4      1    NA
# 3      2    RWmT90rP7wYo57dG1cyvww Zja7ykq3icDzkN20XX6j1w 5      1    NA
# 4      3    0jduztItUhOh3FzKGjMxZQ hr0vxeTzlHx6fTpSSmu2AA 5     NA     1
# 5      4    sxfmzhMvZ8LlI1x4fhNjKg F4kjKxXXyn3e-BYVb1mWcg 4      1     1
# 6      5    Mp7qXWexqoSqKbNh7dYhJg J9f-9Prw2YVM-fiZqv2fmQ 5     NA    NA
# 7      6    5e_JUyKVFpYxl9qHp1MG1Q 7xHbnGo4MXFkBm6gYSu_xg 2      1    NA
# 8      7    D2oYk9ipsvsYP_ls0aL9kg eU_713ec6fTGNO4BegRaww 4     NA     0
# 9      8    CKHk7l_VriSEqPbG1PSLTw epWC7CGRbNHkXM7G2ulYzQ 3      1    NA
# 10     9    iFKNo8gEgKwuWTmRPmJ-MQ ZWq8Fq13JPDAqt7rPjSwcQ 5     NA    NA
# 11    10    QE6JCyys7Mijp5bLVBu2zQ pWJoOfYUWSkro0WNxHspFg 4     NA    NA
# 12    11    _8DNICsYCbIm8-zxWKZPxg 7xHbnGo4MXFkBm6gYSu_xg 2      1    NA
# 13    12    8NfaQ-Nfd_wxzeNNwvKjeA x1Cd2gSPZVeNxDPzzqlClQ 5      1    NA
# 14    13    aVozRweRmtlvEDx2C32pLA cTPdZ9Va0HCLESf5gNnXwA 5      0     1
# 15    14    c4_BcnjSLtBuF_3O4JNnfA lpel3pRFAzlow7u2TJMz4Q 5      1     1
# 16    15    IZUapydWWl2uBFBt2EyC4w hr0vxeTzlHx6fTpSSmu2AA 4     NA     1
# 17    16    COKi3CYcuMxHOsbXkY2ezg J9f-9Prw2YVM-fiZqv2fmQ 5     NA    NA
# 18    17    L944kGO4W-K5OOaFgEmBoA NN6HpdvQlGZUVjBwzhgUWQ 5     NA    NA
# 19    18    daIlNwodR_ounz3pNGOxzg Zja7ykq3icDzkN20XX6j1w 2      1    NA
# 20    19    mwheDblzR5QzxY-ez7iG0A 7xHbnGo4MXFkBm6gYSu_xg 3      1    NA
# 21    20    yt8s2hoXvFIPPLcn0el_bg YgHp9MdZ1vVdYyMEro4TtQ 4     NA     1
# 22    21    dPlw1EBDLQGyMSomQbJreg JZEw18_OhSzFj0IfXF6v6Q 3     NA    NA
# 23    22    Qh8nDgMiI0XCFDx1hQOv1A YgHp9MdZ1vVdYyMEro4TtQ 4      1     1
# 24    23    1w1J_WzXcvKS47aBuat11g Ev142kLmV_ASI9iAl-KfKA 5      1    NA
# 25    24    L5MX4wXzKAtDasGFNRpwnA eigkQ_PuRON8Se265NqQDQ 1     NA    NA
# 26    25    teLazoc6kuaSqid09ZUU1Q wuyJfCF5gWyz9yrFMaGczQ 4     NA    NA
# 27    26    Ci7eLn5l1X1UTIe0COaCrA eU_713ec6fTGNO4BegRaww 5     NA    NA
# 28    27    WbQYxul0O1VFJY7xHpb0Ow CqCWN9aBJf8YNJxyel7psg 4     NA     1
# 29    28    GhbhGFBSwmUitJ2C_dgBqw mJ24zWo_FdE3_9v24sqFiw 1      1    -1
# 30    29    x4OI8tEvVEnNDyZgQeE-IA lpel3pRFAzlow7u2TJMz4Q 5      1     1
# ⋮     ⋮     ⋮                      ⋮                      ⋮     ⋮     ⋮
# 67127 67126 OVgVK3U4rdKJGXMZeq96cQ 6kD0vTLj3oZJm7kXRSvfKw 3     NA    NA
# 67128 67127 gyyJWkPwo_1dNHt5yFO81w R13VkcyUIU3xG2fRFbBvBA 3     NA    NA
# 67129 67128 vE-D7b67zVNmhYBKRy6A0w 8xrwjD-Udv7cm_emVcVo3A 2     NA     0
# 67130 67129 iIROmR9ojmd102UqntYbDw Fq3JQOd0b_8MqENnxSwMDA 5      0    NA
# 67131 67130 crmt_vF8tJL3ptgt9D5nyg Nkb9_PKgnVYZe8W1y_fBRg 4     NA    NA
# 67132 67131 Dd8MvFla3BawPshFS4bMbQ R13VkcyUIU3xG2fRFbBvBA 4      1     0
# 67133 67132 bj5kQsrr-R2LDxWT1S02mQ AlwKuzyrrxlZ04ktebwmcA 5      1    NA
# 67134 67133 142cUPOlVveREeMATIVkjQ M-caugKzJ9qLOmCBfD9Nyg 5     NA     1
# 67135 67134 OM2m2OviX_adiqX8Go0Nhw jUxLgiiYKnsM238eUZUqlA 1      1    NA
# 67136 67135 Fsn4u2RjnCS4kbO0OIqcCQ ly0oNXKOoSZyr0mzOsVJhg 5      1    NA
# 67137 67136 H_auRfRKXlcdLdlMzPIUMQ Nkb9_PKgnVYZe8W1y_fBRg 4     NA     1
# 67138 67137 6Bw43dv2_HPxyAuhqc9puA Y1AyPfNDzNhEpUsfuYP_lA 1      1    NA
# 67139 67138 ZMgeCSq92zwnqLzCG_M3yQ AlwKuzyrrxlZ04ktebwmcA 1     NA     0
# 67140 67139 GMDas-byWibQNNbbzJRWWw 2VEa7rpo68KG0_5pBj0dFA 5      1    NA
# 67141 67140 ECHZ3Pax5085hOi8iBbJQA 6kD0vTLj3oZJm7kXRSvfKw 1     NA    NA
# 67142 67141 1mFiD-v_vN7T79XKnbtnLA 8R6VkHg7pNvW0mW2_KjDDg 1     NA    NA
# 67143 67142 q7fjLQCFUo7TeHLz7pofTw THH2CXT1w2acF7qDECx2yg 3     NA     0
# 67144 67143 IUUfRfNZa6mzv3PsI1ZYgg lHLNQnEHwCJ_CROCfCxEzw 5     NA     1
# 67145 67144 b9hT04XhdlKxjh3qxa9zbQ THH2CXT1w2acF7qDECx2yg 4      1    NA
# 67146 67145 DzFSwIlg_IWfcq1eb8sMIw THH2CXT1w2acF7qDECx2yg 4      1    NA
# 67147 67146 qi0aRkLb7BmGN0fJ-DqfhA DzvNrAo1DJcqA_vZT6cF_g 5      1    NA
# 67148 67147 0fWJb84QEcJdNkX5LmZgiA 8CjI8nebSDB5aINJc3dLwA 5      1    NA
# 67149 67148 6XKw9O6gCzpCyAhuVHDG-w Ve6bA_jf9A7EWKXeyWf7PA 1      0    NA
# 67150 67149 tZzRJSY7J036YzOFCHRvow AhYG10mP_LOHePr_SC4Peg 5     NA     1
# 67151 67150 RJfjZ3m57i9J2D_ev_Amgg AlwKuzyrrxlZ04ktebwmcA 5      1    NA
# 67152 67151 gcNRaJMDlSVs8YlqwpsRuw nR3u-wQ99bop6IdGoU38KQ 1      1    NA
# 67153 67152 yFxDOdiDb8HPaK1io81kiw yT1Ad3auuw1jAJEZHr7Yqw 5      1    NA
# 67154 67153 Z_xmoLgIMB4As90t0a5eBQ R13VkcyUIU3xG2fRFbBvBA 4     NA     0
# 67155 67154 CzYRFCnkbqOVb3WIMMrbfw M-caugKzJ9qLOmCBfD9Nyg 1     NA     1
# 67156 67155 ZhUeFHPAjUbEKRnYO_pl_w o_dWM_hlpgjjd7F15UPjZw 3     NA    NA
#       cheese sauce service salad ⋯ cranberry linguini fennel fryer pea coconut
# 1     NA     NA     0      NA    ⋯ NA        NA       NA     NA    NA  NA
# 2     NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 3     NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 4     NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 5     NA     -1    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 6     NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 7     NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 8     NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 9     NA     NA    NA       0    ⋯ NA        NA       NA     NA    NA  NA
# 10    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 11    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 12    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 13    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 14     0      1    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 15    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 16    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 17    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 18    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 19     0      1    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 20    NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 21    NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 22    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 23    NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 24    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 25    NA     NA     0      NA    ⋯ NA        NA       NA     NA    NA  NA
# 26    NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 27    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 28    NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 29     1      1     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 30    NA      1     1       1    ⋯ NA        NA       NA     NA    NA  NA
# ⋮     ⋮      ⋮     ⋮       ⋮     ⋱ ⋮         ⋮        ⋮      ⋮     ⋮   ⋮
# 67127 NA      1     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67128  0     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67129 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67130 NA     NA     1       0    ⋯ NA        NA       NA     NA    NA  NA
# 67131 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67132  1     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67133 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67134 NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67135 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67136 NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67137 NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67138 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67139 NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67140 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67141 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67142 NA      0    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67143 NA     NA    NA       0    ⋯ NA        NA       NA     NA    NA  NA
# 67144 NA     NA    NA       1    ⋯ NA        NA       NA     NA    NA  NA
# 67145 NA     NA    NA       1    ⋯ NA        NA       NA     NA    NA  NA
# 67146 NA      0    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67147 NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67148 NA     NA     0      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67149  0     NA    -1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67150 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67151 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67152 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67153 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67154 NA     NA    NA      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67155 NA     NA     1      NA    ⋯ NA        NA       NA     NA    NA  NA
# 67156 NA     NA    NA       1    ⋯ NA        NA       NA     NA    NA  NA
#       mixture peach manicotti romaine
# 1     NA      NA    NA        NA
# 2     NA      NA    NA        NA
# 3     NA      NA    NA        NA
# 4     NA      NA    NA        NA
# 5     NA      NA    NA        NA
# 6     NA      NA    NA        NA
# 7     NA      NA    NA        NA
# 8     NA      NA    NA        NA
# 9     NA      NA    NA        NA
# 10    NA      NA    NA        NA
# 11    NA      NA    NA        NA
# 12    NA      NA    NA        NA
# 13    NA      NA    NA        NA
# 14    NA      NA    NA        NA
# 15    NA      NA    NA        NA
# 16    NA      NA    NA        NA
# 17    NA      NA    NA        NA
# 18    NA      NA    NA        NA
# 19    NA      NA    NA        NA
# 20    NA      NA    NA        NA
# 21    NA      NA    NA        NA
# 22    NA      NA    NA        NA
# 23    NA      NA    NA        NA
# 24    NA      NA    NA        NA
# 25    NA      NA    NA        NA
# 26    NA      NA    NA        NA
# 27    NA      NA    NA        NA
# 28    NA      NA    NA        NA
# 29    NA      NA    NA        NA
# 30    NA      NA    NA        NA
# ⋮     ⋮       ⋮     ⋮         ⋮
# 67127 NA      NA    NA        NA
# 67128 NA      NA    NA        NA
# 67129 NA      NA    NA        NA
# 67130 NA      NA    NA        NA
# 67131 NA      NA    NA        NA
# 67132 NA       1    NA        NA
# 67133 NA      NA    NA        NA
# 67134 NA      NA    NA        NA
# 67135 NA      NA    NA        NA
# 67136 NA      NA    NA        NA
# 67137 NA      NA    NA        NA
# 67138 NA      NA    NA        NA
# 67139 NA      NA    NA        NA
# 67140 NA      NA    NA        NA
# 67141 NA      NA    NA        NA
# 67142 NA      NA    NA        NA
# 67143 NA      NA    NA        NA
# 67144 NA      NA    NA        NA
# 67145 NA      NA    NA        NA
# 67146 NA      NA    NA        NA
# 67147 NA      NA    NA        NA
# 67148 NA      NA    NA        NA
# 67149 NA      NA    NA        NA
# 67150 NA      NA    NA        NA
# 67151 NA      NA    NA        NA
# 67152 NA      NA    NA        NA
# 67153 NA      NA    NA        NA
# 67154 NA      NA    NA        NA
# 67155 NA      NA    NA        NA
# 67156 NA      NA    NA        NA

# %%
Word_Data=Word_Review_Matrix[,-c(1,2,3)]
Word_Data
# Out:
#       stars pizza food cheese sauce service salad restaurant crust chicken ⋯
# 1     2     NA    NA   NA     NA     0      NA    NA         NA    NA      ⋯
# 2     4      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 3     5      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 4     5     NA     1   NA     NA    NA      NA     1         NA    NA      ⋯
# 5     4      1     1   NA     -1    NA      NA    NA         NA    NA      ⋯
# 6     5     NA    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 7     2      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 8     4     NA     0   NA     NA    NA      NA    NA         NA    NA      ⋯
# 9     3      1    NA   NA     NA    NA       0    NA         NA    NA      ⋯
# 10    5     NA    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 11    4     NA    NA   NA     NA    NA      NA     1         NA     0      ⋯
# 12    2      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 13    5      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 14    5      0     1    0      1    NA      NA    NA         NA     1      ⋯
# 15    5      1     1   NA     NA    NA      NA    NA         NA    NA      ⋯
# 16    4     NA     1   NA     NA    NA      NA    NA         NA    NA      ⋯
# 17    5     NA    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 18    5     NA    NA   NA     NA    NA      NA    NA         NA     0      ⋯
# 19    2      1    NA    0      1    NA      NA    NA         NA    NA      ⋯
# 20    3      1    NA   NA     NA     1      NA    NA         NA    NA      ⋯
# 21    4     NA     1   NA     NA     1      NA    NA         NA    NA      ⋯
# 22    3     NA    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 23    4      1     1   NA     NA     1      NA    NA         NA    NA      ⋯
# 24    5      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 25    1     NA    NA   NA     NA     0      NA    NA         NA    NA      ⋯
# 26    4     NA    NA   NA     NA     1      NA    NA         NA    NA      ⋯
# 27    5     NA    NA   NA     NA    NA      NA     1         NA    NA      ⋯
# 28    4     NA     1   NA     NA    NA      NA    -1         NA    NA      ⋯
# 29    1      1    -1    1      1     1      NA    NA          1    NA      ⋯
# 30    5      1     1   NA      1     1       1     1          1    NA      ⋯
# ⋮     ⋮     ⋮     ⋮    ⋮      ⋮     ⋮       ⋮     ⋮          ⋮     ⋮       ⋱
# 67127 3     NA    NA   NA      1     1      NA    NA         NA     1      ⋯
# 67128 3     NA    NA    0     NA    NA      NA    NA         NA    NA      ⋯
# 67129 2     NA     0   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67130 5      0    NA   NA     NA     1       0    NA         NA    NA      ⋯
# 67131 4     NA    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67132 4      1     0    1     NA    NA      NA     1         NA     1      ⋯
# 67133 5      1    NA   NA     NA    NA      NA    NA          1    NA      ⋯
# 67134 5     NA     1   NA     NA     1      NA     0         NA    NA      ⋯
# 67135 1      1    NA   NA     NA    NA      NA    NA          1    NA      ⋯
# 67136 5      1    NA   NA     NA     1      NA    NA         NA    NA      ⋯
# 67137 4     NA     1   NA     NA     1      NA    NA         NA    NA      ⋯
# 67138 1      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67139 1     NA     0   NA     NA     1      NA    NA         NA    NA      ⋯
# 67140 5      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67141 1     NA    NA   NA     NA    NA      NA    -1         NA    NA      ⋯
# 67142 1     NA    NA   NA      0    NA      NA     0         NA    NA      ⋯
# 67143 3     NA     0   NA     NA    NA       0    NA         NA    NA      ⋯
# 67144 5     NA     1   NA     NA    NA       1    NA         NA    NA      ⋯
# 67145 4      1    NA   NA     NA    NA       1    NA          0    NA      ⋯
# 67146 4      1    NA   NA      0    NA      NA    NA         NA    NA      ⋯
# 67147 5      1    NA   NA     NA     1      NA    NA         NA     0      ⋯
# 67148 5      1    NA   NA     NA     0      NA    NA         NA    NA      ⋯
# 67149 1      0    NA    0     NA    -1      NA    NA         NA    NA      ⋯
# 67150 5     NA     1   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67151 5      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67152 1      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67153 5      1    NA   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67154 4     NA     0   NA     NA    NA      NA    NA         NA    NA      ⋯
# 67155 1     NA     1   NA     NA     1      NA     0         NA    NA      ⋯
# 67156 3     NA    NA   NA     NA    NA       1    NA         NA    NA      ⋯
#       cranberry linguini fennel fryer pea coconut mixture peach manicotti
# 1     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 2     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 3     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 4     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 5     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 6     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 7     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 8     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 9     NA        NA       NA     NA    NA  NA      NA      NA    NA
# 10    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 11    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 12    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 13    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 14    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 15    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 16    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 17    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 18    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 19    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 20    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 21    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 22    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 23    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 24    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 25    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 26    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 27    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 28    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 29    NA        NA       NA     NA    NA  NA      NA      NA    NA
# 30    NA        NA       NA     NA    NA  NA      NA      NA    NA
# ⋮     ⋮         ⋮        ⋮      ⋮     ⋮   ⋮       ⋮       ⋮     ⋮
# 67127 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67128 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67129 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67130 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67131 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67132 NA        NA       NA     NA    NA  NA      NA       1    NA
# 67133 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67134 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67135 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67136 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67137 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67138 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67139 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67140 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67141 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67142 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67143 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67144 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67145 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67146 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67147 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67148 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67149 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67150 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67151 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67152 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67153 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67154 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67155 NA        NA       NA     NA    NA  NA      NA      NA    NA
# 67156 NA        NA       NA     NA    NA  NA      NA      NA    NA
#       romaine
# 1     NA
# 2     NA
# 3     NA
# 4     NA
# 5     NA
# 6     NA
# 7     NA
# 8     NA
# 9     NA
# 10    NA
# 11    NA
# 12    NA
# 13    NA
# 14    NA
# 15    NA
# 16    NA
# 17    NA
# 18    NA
# 19    NA
# 20    NA
# 21    NA
# 22    NA
# 23    NA
# 24    NA
# 25    NA
# 26    NA
# 27    NA
# 28    NA
# 29    NA
# 30    NA
# ⋮     ⋮
# 67127 NA
# 67128 NA
# 67129 NA
# 67130 NA
# 67131 NA
# 67132 NA
# 67133 NA
# 67134 NA
# 67135 NA
# 67136 NA
# 67137 NA
# 67138 NA
# 67139 NA
# 67140 NA
# 67141 NA
# 67142 NA
# 67143 NA
# 67144 NA
# 67145 NA
# 67146 NA
# 67147 NA
# 67148 NA
# 67149 NA
# 67150 NA
# 67151 NA
# 67152 NA
# 67153 NA
# 67154 NA
# 67155 NA
# 67156 NA

# %% [markdown]
# # ANOVA
#
# First we use ANOVA, our H0: the mean star rating of positive, neutral and negative reviews is the same. our H1: the mean is not the same.

# %% [markdown]
# # Assumption Check

# %%
g1=ggplot(Word_Data["stars"], aes(x=stars))+geom_histogram(color='blue',fill='blue',alpha=0.5,binwidth=1)+ggtitle("Histogram of Stars in Review")
g1
ggsave("figure/Histogram_of_Stars_in_Review.jpeg",g1)
g2=ggplot(Word_Data[which(Word_Data[,2]==1),], aes(x=stars))+geom_histogram(color='blue',fill='blue',alpha=0.5,binwidth=1)+ggtitle("Histogram of Stars in Positive Review of Pizza")
g2
ggsave("figure/Histogram_of_Stars_in_Positive_Review_of_Pizza.jpeg",g2)
g3=ggplot(Word_Data[which(Word_Data[,2]==-1),], aes(x=stars))+geom_histogram(color='blue',fill='blue',alpha=0.5,binwidth=1)+ggtitle("Histogram of Stars in Negative Review of Pizza")
g3
ggsave("figure/Histogram_of_Stars_in_Negative_Review_of_Pizza.jpeg",g3)
g4=ggplot(Word_Data[which(Word_Data[,2]==0),], aes(x=stars))+geom_histogram(color='blue',fill='blue',alpha=0.5,binwidth=1)+ggtitle("Histogram of Stars in Neutral Review of Pizza")
g4
ggsave("figure/Histogram_of_Stars_in_Neutral_Review_of_Pizza.jpeg",g4)
# Out:
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# As you can see. The star distribution is obviously not normal. There may be problem for ANOVA test. But our sample is enough.
#
# We hold that all review is independent
#
# Mean_Difference_P_C is difference with mean review star rating between positive with neutral
#
# Mean_Difference_C_N is that between neutral with negative.

# %%
Word=c()
ANOVA_P_Value=c()
Mean_Difference_P_C=c()
Mean_Difference_C_N=c()
for(i in 2:(length(Word_Data))){
    Rating_Positive=Word_Data[which(Word_Data[,i]==1),]$stars
    Rating_Negative=Word_Data[which(Word_Data[,i]==-1),]$stars
    Rating_Neutral=Word_Data[which(Word_Data[,i]==0),]$stars
    if(length(Rating_Positive)>30 & length(Rating_Negative)>30 & length(Rating_Neutral)>30){
        ANOVA_P_Value=c(ANOVA_P_Value,anova(lm(as.numeric(Word_Data[which(Word_Data[,i]!='NA'),]$stars)~as.factor(Word_Data[which(Word_Data[,i]!='NA'),i])))$"Pr(>F)"[1])
        Mean_Difference_P_C=c(Mean_Difference_P_C,mean(Rating_Positive)-mean(Rating_Neutral))
        Mean_Difference_C_N=c(Mean_Difference_C_N,mean(Rating_Neutral)-mean(Rating_Negative))
        Word=c(Word,colnames(Word_Data)[i])
        
    }
}

# %%
ANOVA_Results=cbind(Word,ANOVA_P_Value,Mean_Difference_P_C,Mean_Difference_C_N)

# %%
ANOVA_Results
# Out:
#       Word       ANOVA_P_Value         Mean_Difference_P_C Mean_Difference_C_N
#  [1,] pizza      0                     0.76696025041681    0.90564738170601
#  [2,] food       0                     0.98981566696104    0.952735967365247
#  [3,] cheese     5.39391231442947e-176 0.56716383606221    0.624936637041535
#  [4,] sauce      1.90418323464796e-214 0.624807098765432   0.588412817579484
#  [5,] service    0                     1.02953440311669    1.31231420510815
#  [6,] salad      8.95900323600436e-206 0.634078091683731   0.923495783314999
#  [7,] restaurant 3.01874104318093e-257 0.707279625450837   0.890582563904115
#  [8,] crust      7.09448841502016e-150 0.554776559777461   0.500703624519458
#  [9,] chicken    1.45040690025919e-111 0.523311982192768   0.846554698994668
# [10,] beer       4.0604942696048e-79   0.405548670513129   0.759241231496504
# [11,] menu       1.08535751547308e-112 0.487688042600122   0.500909816210397
# [12,] delivery   2.06419299819947e-161 0.901224043736764   0.860507414768888
# [13,] staff      0                     1.18141063880447    1.02470897325871
# [14,] price      2.18150975352763e-135 0.528109797915946   0.751927115849396
# [15,] bread      6.97548900111939e-89  0.682798206144402   0.426503904185105
# [16,] dinner     6.90799968742562e-93  0.510325814342683   0.889372259960495
# [17,] meal       1.16063292955276e-122 0.733690309613715   0.66647854971733
# [18,] pasta      1.55532684748982e-56  0.49990221810509    0.665639589169001
# [19,] server     5.09808533332598e-136 0.831616137784593   0.66501817255207
# [20,] flavor     1.98885677748211e-80  0.678953400795789   0.324722776470828
# [21,] sandwich   3.8052627837295e-71   0.62558522789337    0.790927108566395
# [22,] lunch      7.40948510418239e-66  0.453405850718256   0.834704460386775
# [23,] pie        1.8492967456538e-20   0.282735323418603   0.388773299891695
# [24,] pepperoni  5.7028002502602e-47   0.499417758526525   0.53558031911449
# [25,] location   2.28611792260477e-52  0.536247417212689   0.602418745275888
# [26,] fry        4.44103701367703e-43  0.604780884099964   0.683351384805817
# [27,] meatball   1.34153959742355e-26  0.414529728750623   0.539198998748436
# [28,] waitress   6.18226638953722e-111 0.963769336021585   0.471605187578532
# [29,] wine       1.32004065397348e-36  0.330225866507842   0.812889771598808
# [30,] burger     3.93675016061414e-34  0.628107702411108   0.531684747422111
# [31,] ⋮          ⋮                     ⋮                   ⋮
# [32,] gnocchi    6.38517078736599e-07  0.279990130767334   0.49047619047619
# [33,] butter     1.6129444450951e-11   0.447368421052632   0.561592152424071
# [34,] ravioli    1.07735162472042e-12  0.512333860024166   0.810079575596817
# [35,] taco       8.87148864022776e-07  0.60210258043963    0.132709807886755
# [36,] margherita 1.29619879281061e-09  0.460122655637168   0.333125433125433
# [37,] chocolate  0.0110002764705783    0.0868595239412215  0.469471947194719
# [38,] coffee     1.92256775521145e-10  0.353819444444444   0.937373737373737
# [39,] takeout    2.5265118997296e-15   0.449260752688172   0.756989247311828
# [40,] management 2.25945411094333e-21  0.737895133911731   0.592727272727273
# [41,] building   0.000144152868614601  0.288160115746323   0.384080686929263
# [42,] tv         0.0095271211330021    0.206315977813563   0.421634332745444
# [43,] soda       1.65091587577995e-11  0.404872853148715   1.12347641759406
# [44,] attitude   7.79170091764663e-17  0.907150932730356   0.222594800463653
# [45,] salt       4.57962400529341e-06  0.557055353901996   -0.0145676691729322
# [46,] seafood    2.53955346969983e-08  0.483420313127259   0.662045298558682
# [47,] caesar     1.05332791775901e-10  0.625159914712154   0.823788036561379
# [48,] grease     5.35883478386522e-09  0.680365296803653   0.318181818181818
# [49,] buffet     7.80611665388276e-07  0.541917410251089   0.720069547938401
# [50,] worker     1.18582098600054e-26  1.25855896173641    0.68458295694068
# [51,] tiramisu   0.0516307907244567    0.0150862068965516  0.453663793103448
# [52,] doughy     1.77770849292409e-12  0.8501498351813     0.0741570635936837
# [53,] cooking    3.72333926190068e-05  0.569503029373418   0.0595304251180884
# [54,] diner      7.48732244160397e-05  0.550837269214255   0.174979724249797
# [55,] fee        0.0255007373490524    0.370896300156331   0.418953323903819
# [56,] wing       2.6494235746554e-106  0.906976825818046   0.621732026143791
# [57,] topping    6.7812555423856e-93   0.646777668895467   0.687808589062232
# [58,] dressing   7.75071377269601e-51  0.702261636144199   0.745783628136569
# [59,] olive      2.17867728013476e-08  0.338491814465275   0.430125317890737
# [60,] serving    6.69558256734629e-21  0.555955628799734   0.965398773006135
# [61,] seasoning  1.63254399954855e-08  0.69091743119266    0.200322580645162

# %% [markdown]
# Check for "cheese", the three star review are:

# %%
Rating_Positive=Word_Data[which(Word_Data[,4]==1),]$stars
Rating_Negative=Word_Data[which(Word_Data[,4]==-1),]$stars
Rating_Neutral=Word_Data[which(Word_Data[,4]==0),]$stars

# %%
mean(Rating_Positive)-mean(Rating_Neutral)
# Out:
# [1] 0.5671638

# %%
mean(Rating_Neutral)-mean(Rating_Negative)
# Out:
# [1] 0.6249366

# %%
Factor=as.factor(c(rep("Pos",length(Rating_Positive)),rep("Neg",length(Rating_Negative)),rep("Neu",length(Rating_Neutral))))

# %%
anova(lm(c(Rating_Positive,Rating_Negative,Rating_Neutral)~Factor))
# Out:
#           Df    Sum Sq    Mean Sq    F value  Pr(>F)
# Factor        2  1415.129 707.564503 418.3859 5.393912e-176
# Residuals 11260 19042.648   1.691177       NA            NA

# %% [markdown]
# No problems.
#
# Our results show that for most of words, there are significant difference among the three kinds of review toward most of words except:

# %%
ANOVA_Results[as.numeric(ANOVA_Results[,2])>0.05,]
# Out:
#                 Word        ANOVA_P_Value  Mean_Difference_P_C
#           "tiramisu" "0.0516307907244567" "0.0150862068965516"
#  Mean_Difference_C_N
#  "0.453663793103448"

# %% [markdown]
# And most of the difference between star rating of positive with neutral and neutral with negative is larger than 0. Which means that postive review usually have significant high star rating.

# %%
ANOVA_Results[as.numeric(ANOVA_Results[,3])<0 | as.numeric(ANOVA_Results[,4])<0,]
# Out:
#                   Word          ANOVA_P_Value    Mean_Difference_P_C
#                 "salt" "4.57962400529341e-06"    "0.557055353901996"
#    Mean_Difference_C_N
#  "-0.0145676691729322"

# %% [markdown]
# There is some exception.
#
# But the difference between positive and negative is always larger than 0. Therefore we will pay attention to the difference between positive and negative reviews. Find that words whose difference is significant.

# %% [markdown]
# # T Test

# %% [markdown]
# Compared with linear regression to test whether a noun exist or not can increase star rating. The data here may not be good to linear regression. Because there are four kinds of input. 1, -1, 0 and np.nan. It is strange to take no review as 0 here. So here we only use unpaired T test
#
# As I mention before, the distribution of review star rating is not normality. Although Welch test is robust to non normality, we will choose the words with enough reviews to do our test.
#
# T test hypothesis:
#
# H0: the mean star rating of review with positive attitude toward some noun is larger than that with negative attitude.
#
# H1: the mean of positive is smaller than negative.
#
#
# We only consider the word whose review number is larger than 30.

# %%
Word=c()
T_Test_P_Value=c()
Wilcoxon_Test_P_Value=c()
Mean_Difference=c()
for(i in 2:(length(Word_Data))){
    Rating_Positive=Word_Data[which(Word_Data[,i]==1),]$stars
    Rating_Negative=Word_Data[which(Word_Data[,i]==-1),]$stars
    if(length(Rating_Positive)>30 & length(Rating_Negative)>30){
        T_Test_P_Value=c(T_Test_P_Value,t.test(Rating_Positive,Rating_Negative,alternative = c("greater"),mu = 0, paired = FALSE, var.equal = FALSE, conf.level = 0.95)$p.value)
        Wilcoxon_Test_P_Value=c(Wilcoxon_Test_P_Value,wilcox.test(Rating_Positive,Rating_Negative, alternative = "greater",mu = 0, paired = FALSE, conf.level = 0.95)$p.value)
        Mean_Difference=c(Mean_Difference,mean(Rating_Positive)-mean(Rating_Negative))
        Word=c(Word,colnames(Word_Data)[i])
        
    }
}

# %%
mean(Word_Data[which(Word_Data[,4]==1),]$stars)
mean(Word_Data[which(Word_Data[,4]==-1),]$stars)
# Out:
# [1] 3.96681
# [1] 2.774709

# %%
T_Sig=T_Test_P_Value<0.05
Wilcoxon_Sig=Wilcoxon_Test_P_Value<0.05
Final_Results=cbind(Word,T_Test_P_Value,T_Sig,Mean_Difference)
Final_Results
# Out:
#       Word       T_Test_P_Value        T_Sig Mean_Difference
#  [1,] pizza      0                     TRUE  1.67260763212282
#  [2,] food       0                     TRUE  1.94255163432629
#  [3,] cheese     1.72793897005677e-75  TRUE  1.19210047310374
#  [4,] sauce      5.41046887267871e-88  TRUE  1.21321991634492
#  [5,] service    0                     TRUE  2.34184860822483
#  [6,] salad      4.95722666643119e-89  TRUE  1.55757387499873
#  [7,] restaurant 1.53314451824504e-150 TRUE  1.59786218935495
#  [8,] crust      8.66666924484695e-46  TRUE  1.05548018429692
#  [9,] chicken    5.32811692018839e-53  TRUE  1.36986668118744
# [10,] beer       1.14266448479644e-34  TRUE  1.16478990200963
# [11,] menu       1.73442634404613e-55  TRUE  0.988597858810519
# [12,] delivery   1.61980566449239e-119 TRUE  1.76173145850565
# [13,] staff      1.13914799993408e-178 TRUE  2.20611961206318
# [14,] price      1.82515751460448e-74  TRUE  1.28003691376534
# [15,] bread      6.29154084967421e-30  TRUE  1.10930211032951
# [16,] dinner     1.36880339794677e-46  TRUE  1.39969807430318
# [17,] meal       6.69466426873613e-54  TRUE  1.40016885933104
# [18,] pasta      1.24441469183156e-27  TRUE  1.16554180727409
# [19,] server     3.21334091745768e-80  TRUE  1.49663431033666
# [20,] flavor     3.65092765761976e-25  TRUE  1.00367617726662
# [21,] sandwich   1.52718852150187e-31  TRUE  1.41651233645976
# [22,] lunch      7.99232587230184e-30  TRUE  1.28811031110503
# [23,] pie        1.98735378486248e-10  TRUE  0.671508623310297
# [24,] pepperoni  1.18085585791935e-17  TRUE  1.03499807764102
# [25,] location   4.33394357440575e-35  TRUE  1.13866616248858
# [26,] fry        1.0667818854123e-18   TRUE  1.28813226890578
# [27,] meatball   1.39770697275583e-11  TRUE  0.953728727499059
# [28,] waitress   3.39605476131996e-81  TRUE  1.43537452360012
# [29,] wine       1.0977077919397e-18   TRUE  1.14311563810665
# [30,] burger     1.75361379229487e-13  TRUE  1.15979244983322
# [31,] ⋮          ⋮                     ⋮     ⋮
# [32,] gnocchi    6.80433560526559e-05  TRUE  0.770466321243524
# [33,] butter     4.78079849456532e-07  TRUE  1.0089605734767
# [34,] ravioli    2.20336380207774e-07  TRUE  1.32241343562098
# [35,] taco       0.00247424442971542   TRUE  0.734812388326385
# [36,] margherita 0.000598137304361451  TRUE  0.793248088762601
# [37,] chocolate  0.00829799970640048   TRUE  0.556331471135941
# [38,] coffee     1.04194657808968e-07  TRUE  1.29119318181818
# [39,] takeout    6.09234737802911e-11  TRUE  1.20625
# [40,] management 1.05710518252924e-23  TRUE  1.330622406639
# [41,] building   0.00022824525639765   TRUE  0.672240802675586
# [42,] tv         0.0116791966177037    TRUE  0.627950310559006
# [43,] soda       2.56133450924509e-11  TRUE  1.52834927074278
# [44,] attitude   3.78023484092587e-14  TRUE  1.12974573319401
# [45,] salt       0.0062959094370556    TRUE  0.542487684729064
# [46,] seafood    6.19920670649216e-05  TRUE  1.14546561168594
# [47,] caesar     3.7563993015828e-09   TRUE  1.44894795127353
# [48,] grease     8.12600014239701e-07  TRUE  0.998547114985471
# [49,] buffet     2.38204308105809e-06  TRUE  1.26198695818949
# [50,] worker     2.94177863560417e-22  TRUE  1.94314191867709
# [51,] tiramisu   0.0221229904362486    TRUE  0.46875
# [52,] doughy     0.000768621739582069  TRUE  0.924306898774984
# [53,] cooking    0.00084742047428249   TRUE  0.629033454491506
# [54,] diner      0.00301063971229863   TRUE  0.725816993464052
# [55,] fee        0.0038787471345197    TRUE  0.78984962406015
# [56,] wing       2.58962023512387e-44  TRUE  1.52870885196184
# [57,] topping    1.36330074031575e-43  TRUE  1.3345862579577
# [58,] dressing   1.3802599382966e-22   TRUE  1.44804526428077
# [59,] olive      3.72887646826999e-05  TRUE  0.768617132356012
# [60,] serving    3.46386374778342e-16  TRUE  1.52135440180587
# [61,] seasoning  0.000295955148446543  TRUE  0.891240011837822

# %%
Final_Results=Final_Results[which(Final_Results[,3]==TRUE),]

# %%
Positive=Final_Results[,4]>0
which(Positive==FALSE)
# Out:
# integer(0)

# %%
Final_Results
# Out:
#       Word       T_Test_P_Value        T_Sig Mean_Difference
#  [1,] pizza      0                     TRUE  1.67260763212282
#  [2,] food       0                     TRUE  1.94255163432629
#  [3,] cheese     1.72793897005677e-75  TRUE  1.19210047310374
#  [4,] sauce      5.41046887267871e-88  TRUE  1.21321991634492
#  [5,] service    0                     TRUE  2.34184860822483
#  [6,] salad      4.95722666643119e-89  TRUE  1.55757387499873
#  [7,] restaurant 1.53314451824504e-150 TRUE  1.59786218935495
#  [8,] crust      8.66666924484695e-46  TRUE  1.05548018429692
#  [9,] chicken    5.32811692018839e-53  TRUE  1.36986668118744
# [10,] beer       1.14266448479644e-34  TRUE  1.16478990200963
# [11,] menu       1.73442634404613e-55  TRUE  0.988597858810519
# [12,] delivery   1.61980566449239e-119 TRUE  1.76173145850565
# [13,] staff      1.13914799993408e-178 TRUE  2.20611961206318
# [14,] price      1.82515751460448e-74  TRUE  1.28003691376534
# [15,] bread      6.29154084967421e-30  TRUE  1.10930211032951
# [16,] dinner     1.36880339794677e-46  TRUE  1.39969807430318
# [17,] meal       6.69466426873613e-54  TRUE  1.40016885933104
# [18,] pasta      1.24441469183156e-27  TRUE  1.16554180727409
# [19,] server     3.21334091745768e-80  TRUE  1.49663431033666
# [20,] flavor     3.65092765761976e-25  TRUE  1.00367617726662
# [21,] sandwich   1.52718852150187e-31  TRUE  1.41651233645976
# [22,] lunch      7.99232587230184e-30  TRUE  1.28811031110503
# [23,] pie        1.98735378486248e-10  TRUE  0.671508623310297
# [24,] pepperoni  1.18085585791935e-17  TRUE  1.03499807764102
# [25,] location   4.33394357440575e-35  TRUE  1.13866616248858
# [26,] fry        1.0667818854123e-18   TRUE  1.28813226890578
# [27,] meatball   1.39770697275583e-11  TRUE  0.953728727499059
# [28,] waitress   3.39605476131996e-81  TRUE  1.43537452360012
# [29,] wine       1.0977077919397e-18   TRUE  1.14311563810665
# [30,] burger     1.75361379229487e-13  TRUE  1.15979244983322
# [31,] ⋮          ⋮                     ⋮     ⋮
# [32,] gnocchi    6.80433560526559e-05  TRUE  0.770466321243524
# [33,] butter     4.78079849456532e-07  TRUE  1.0089605734767
# [34,] ravioli    2.20336380207774e-07  TRUE  1.32241343562098
# [35,] taco       0.00247424442971542   TRUE  0.734812388326385
# [36,] margherita 0.000598137304361451  TRUE  0.793248088762601
# [37,] chocolate  0.00829799970640048   TRUE  0.556331471135941
# [38,] coffee     1.04194657808968e-07  TRUE  1.29119318181818
# [39,] takeout    6.09234737802911e-11  TRUE  1.20625
# [40,] management 1.05710518252924e-23  TRUE  1.330622406639
# [41,] building   0.00022824525639765   TRUE  0.672240802675586
# [42,] tv         0.0116791966177037    TRUE  0.627950310559006
# [43,] soda       2.56133450924509e-11  TRUE  1.52834927074278
# [44,] attitude   3.78023484092587e-14  TRUE  1.12974573319401
# [45,] salt       0.0062959094370556    TRUE  0.542487684729064
# [46,] seafood    6.19920670649216e-05  TRUE  1.14546561168594
# [47,] caesar     3.7563993015828e-09   TRUE  1.44894795127353
# [48,] grease     8.12600014239701e-07  TRUE  0.998547114985471
# [49,] buffet     2.38204308105809e-06  TRUE  1.26198695818949
# [50,] worker     2.94177863560417e-22  TRUE  1.94314191867709
# [51,] tiramisu   0.0221229904362486    TRUE  0.46875
# [52,] doughy     0.000768621739582069  TRUE  0.924306898774984
# [53,] cooking    0.00084742047428249   TRUE  0.629033454491506
# [54,] diner      0.00301063971229863   TRUE  0.725816993464052
# [55,] fee        0.0038787471345197    TRUE  0.78984962406015
# [56,] wing       2.58962023512387e-44  TRUE  1.52870885196184
# [57,] topping    1.36330074031575e-43  TRUE  1.3345862579577
# [58,] dressing   1.3802599382966e-22   TRUE  1.44804526428077
# [59,] olive      3.72887646826999e-05  TRUE  0.768617132356012
# [60,] serving    3.46386374778342e-16  TRUE  1.52135440180587
# [61,] seasoning  0.000295955148446543  TRUE  0.891240011837822

# %% [markdown]
# Check, for cheese:

# %%
t.test(Word_Data[which(Word_Data[,4]==1),]$stars,Word_Data[which(Word_Data[,4]==-1),]$stars,alternative = c("greater"))$p.value
# Out:
# [1] 1.727939e-75

# %% [markdown]
# No problems

# %%
dim(Final_Results)
# Out:
# [1] 110   4

# %% [markdown]
# Therefore, our function gives a list on important business or food. Where there are significant difference between the star rating of positve reviews and negative reviews of them. And for all words, the mean of positive reviews star rating is larger than negative one significantly

# %%
write.csv(Final_Results,"data/Results_Analysis_Noun_Attitude.csv")
